# %%
import tensorflow as tf

# %%
from tensorflow.keras.layers import Dense, Conv2D, Conv2DTranspose, Flatten, Input, MaxPooling2D, LeakyReLU, BatchNormalization, PReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import PiecewiseConstantDecay
from tensorflow.keras.preprocessing import image_dataset_from_directory

from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input

# from PIL import Image
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.preprocessing.image import load_img, img_to_array
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
import cv2

import random
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
from glob import glob
import os
from tqdm import tqdm
import shutil

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  # 텐서플로가 첫 번째 GPU만 사용하도록 제한
  try:
    tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
  except RuntimeError as e:
    # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
    print(e)

# %%
image_size = (64,64,3)
H = image_size[0]
W = image_size[1]
C = image_size[2]

target_size = (256,256,3)
T_H = target_size[0]
T_W = target_size[1]
T_C = target_size[2]

batch_size = 2
epochs = 1000
sample_every = 5

# %%
def g_layer_block(kernel_size, units, strides, x):

  x = Conv2D(filters = units, kernel_size= kernel_size, strides = strides, padding = "same")(x)
  
  x = BatchNormalization(momentum = 0.5)(x)
  x = PReLU(shared_axes = [1,2])(x)
  x = Conv2D(filters = units, kernel_size= kernel_size, strides = strides, padding = "same")(x)
  
  
  x = BatchNormalization()(x)
  
  return x

# %%
def g_layer_block_2(kernel_size, units, strides, x, scale):
  x = Conv2D(filters = units, kernel_size= kernel_size, strides = strides, padding = "same")(x)
  x = tf.nn.depth_to_space(x,scale)
  x = PReLU(shared_axes = [1,2])(x)

  return x

# %%
def g_layer_block_3(x, connect_x):
  x = g_layer_block(kernel_size=3, units = H, strides = 1, x= x)
  x = tf.keras.layers.add([connect_x, x])
  new_connect_x = x

  return x, new_connect_x

# %%
def build_generator(img_size):
  i = Input(shape = img_size)
  x = Conv2D(filters = H, kernel_size = 9, strides = 1, padding = "same")(i)
  x = PReLU(shared_axes = [1,2])(x)

  connect_x = x
  connect_x_2 = connect_x

  num_residual = 16
  for j in range(num_residual):
    x, connect_x = g_layer_block_3(x, connect_x= connect_x)
  
  
  x = Conv2D(kernel_size=3, filters = H, strides = 1, padding = "same")(x)
  x = BatchNormalization(momentum = 0.5)(x)
  x = tf.keras.layers.add([connect_x_2,x])

  x = g_layer_block_2(kernel_size=3, units= H*4, strides= 1, x= x, scale = 2)

  x = g_layer_block_2(kernel_size=3, units= H*4, strides= 1, x= x, scale = 2)
  # x = Conv2D(filters= 3, kernel_size=9, strides = 1, padding = "same" )(x)

  x = Conv2D(filters= 3, kernel_size=9, strides = 1, padding = "same", activation = "tanh")(x)

  model = Model(inputs = i, outputs = x)
  return model

# %%
def d_layer_block(kernel_size,units,strides,x):
  x = Conv2D(filters = units, kernel_size= kernel_size, strides = strides, padding = "same")(x)
  x = BatchNormalization(momentum=0.8)(x)
  x = LeakyReLU()(x)

  return x

# %%
def build_discriminator(img_size):
  i = Input(shape = img_size)
  x = Conv2D(filters=H, kernel_size=3, strides = 1, activation= LeakyReLU())(i)
  x = d_layer_block(3,H,2,x)
  x = d_layer_block(3,H*2,1,x)
  x = d_layer_block(3,H*2,2,x)
  x = d_layer_block(3,H*4,1,x)
  x = d_layer_block(3,H*4,2,x)
  x = d_layer_block(3,H*8,1,x)
  x = d_layer_block(3,H*8,2,x)

  x = Flatten()(x)
  x = Dense(H*16)(x)
  x = LeakyReLU()(x)
  x = Dense(1, activation = "sigmoid")(x)

  model = Model(inputs = i, outputs = x)
  return model

# %%
discriminator = build_discriminator(img_size=(T_H,T_W,T_C))

generator = build_generator(img_size = (H,W,C))

z = Input(shape = (H,W,C))

sample_img= generator(z, training = False)

fake_pre = discriminator(sample_img, training = False)

# %%
generator.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 64)   15616       ['input_2[0][0]']
#
#  p_re_lu (PReLU)                (None, 64, 64, 64)   64          ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 64)   36928       ['p_re_lu[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  p_re_lu_1 (PReLU)              (None, 64, 64, 64)   64          ['batch_normalization_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_10[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 64, 64, 64)   0           ['p_re_lu[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 64)   36928       ['add[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_11[0][0]']
#  rmalization)
#
#  p_re_lu_2 (PReLU)              (None, 64, 64, 64)   64          ['batch_normalization_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_2[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  add_1 (Add)                    (None, 64, 64, 64)   0           ['add[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 64)   36928       ['add_1[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  p_re_lu_3 (PReLU)              (None, 64, 64, 64)   64          ['batch_normalization_11[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_3[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 64, 64, 64)   0           ['add_1[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   36928       ['add_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  p_re_lu_4 (PReLU)              (None, 64, 64, 64)   64          ['batch_normalization_13[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 64, 64, 64)   0           ['add_2[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 64)   36928       ['add_3[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  p_re_lu_5 (PReLU)              (None, 64, 64, 64)   64          ['batch_normalization_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_5[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 64, 64, 64)   0           ['add_3[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 64)   36928       ['add_4[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 64, 64, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  p_re_lu_6 (PReLU)              (None, 64, 64, 64)   64          ['batch_normalization_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_6[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 64, 64, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 64, 64, 64)   0           ['add_4[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 64)   36928       ['add_5[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  p_re_lu_7 (PReLU)              (None, 64, 64, 64)   64          ['batch_normalization_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_7[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 64)  256         ['conv2d_22[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 64, 64, 64)   0           ['add_5[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 64)   36928       ['add_6[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  p_re_lu_8 (PReLU)              (None, 64, 64, 64)   64          ['batch_normalization_21[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_8[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 64, 64, 64)   0           ['add_6[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 64)   36928       ['add_7[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  p_re_lu_9 (PReLU)              (None, 64, 64, 64)   64          ['batch_normalization_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_9[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 64, 64, 64)   0           ['add_7[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 64)   36928       ['add_8[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  p_re_lu_10 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_25[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_10[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 64, 64, 64)   0           ['add_8[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 64)   36928       ['add_9[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 64)  256         ['conv2d_29[0][0]']
#  ormalization)
#
#  p_re_lu_11 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_11[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 64, 64, 64)  256         ['conv2d_30[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 64, 64, 64)   0           ['add_9[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 64)   36928       ['add_10[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 64, 64, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  p_re_lu_12 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_12[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 64, 64, 64)  256         ['conv2d_32[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 64, 64, 64)   0           ['add_10[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 64)   36928       ['add_11[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 64)  256         ['conv2d_33[0][0]']
#  ormalization)
#
#  p_re_lu_13 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_31[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_13[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 64)  256         ['conv2d_34[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 64, 64, 64)   0           ['add_11[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 64, 64, 64)   36928       ['add_12[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  p_re_lu_14 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_33[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_14[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 64, 64, 64)  256         ['conv2d_36[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 64, 64, 64)   0           ['add_12[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 64, 64, 64)   36928       ['add_13[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 64)  256         ['conv2d_37[0][0]']
#  ormalization)
#
#  p_re_lu_15 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_35[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_15[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 64, 64, 64)  256         ['conv2d_38[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 64, 64, 64)   0           ['add_13[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 64, 64, 64)   36928       ['add_14[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 64, 64, 64)  256         ['conv2d_39[0][0]']
#  ormalization)
#
#  p_re_lu_16 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_37[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_16[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 64, 64, 64)  256         ['conv2d_40[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 64, 64, 64)   0           ['add_14[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 64)   36928       ['add_15[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 64, 64, 64)  256         ['conv2d_41[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 64, 64, 64)   0           ['p_re_lu[0][0]',
#                                                                   'batch_normalization_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 64, 64, 256)  147712      ['add_16[0][0]']
#
#  tf.nn.depth_to_space (TFOpLamb  (None, 128, 128, 64  0          ['conv2d_42[0][0]']
#  da)                            )
#
#  p_re_lu_17 (PReLU)             (None, 128, 128, 64  64          ['tf.nn.depth_to_space[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 128, 128, 25  147712      ['p_re_lu_17[0][0]']
#                                 6)
#
#  tf.nn.depth_to_space_1 (TFOpLa  (None, 256, 256, 64  0          ['conv2d_43[0][0]']
#  mbda)                          )
#
#  p_re_lu_18 (PReLU)             (None, 256, 256, 64  64          ['tf.nn.depth_to_space_1[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 3)  15555       ['p_re_lu_18[0][0]']
#
# ==================================================================================================
# Total params: 1,554,883
# Trainable params: 1,550,659
# Non-trainable params: 4,224
# __________________________________________________________________________________________________

# %% [markdown]
# Pretrained model -> VGG19_model -> perceptual_model? -> content loss

# %%
# Calling VGG 19 network for Loss
vgg = VGG19(include_top= False, weights = "imagenet", input_shape = (T_H, T_W, T_C))
# vgg = VGG19(include_top= False, weights = "imagenet", input_shape = (None, T_W, T_C))
img = Input(shape = (T_H, T_W, T_C))

VGG19_model = Model(inputs= vgg.input, outputs = vgg.layers[10].output)

VGG19_model.trainable = False

# %%
VGG19_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
# =================================================================
# Total params: 2,325,568
# Trainable params: 0
# Non-trainable params: 2,325,568
# _________________________________________________________________

# %%
# This is my image result file path
file_path = "Result/Sr_gan"
if not os.path.exists(file_path):
  os.makedirs(file_path)

# %%
# This is my check point file path
check_path = "Check_point/Sr_gan"
if not os.path.exists(check_path):
  os.makedirs(check_path)
check_point = tf.train.Checkpoint(generator = generator, discriminator = discriminator)
check_point_manager = tf.train.CheckpointManager(checkpoint=check_point, directory= check_path, max_to_keep= 5)

# %%
# check_point.restore(check_point_manager.latest_checkpoint)

# %%
def image_to_numpy(batch_size, batch, img_path):
  
  batch_np_64 = np.zeros((1, H, W, C))
  batch_np_128 = np.zeros((1, T_H, T_W, T_C))

  for img_in_path in img_path[batch:batch + batch_size]:
    image_open = cv2.imread(img_in_path)
    image_open = cv2.cvtColor(image_open, cv2.COLOR_BGR2RGB)

    image_64 = cv2.resize(image_open, (H,W) , interpolation=cv2.INTER_CUBIC)
    image_128 = cv2.resize(image_open, (T_H, T_W))

    image_64 = np.expand_dims(image_64, axis = 0)
    image_128 = np.expand_dims(image_128, axis = 0)

    batch_np_64 = np.append(batch_np_64, image_64, axis = 0)
    batch_np_128 = np.append(batch_np_128, image_128, axis = 0)

  batch_np_64 = np.delete(batch_np_64, 0, axis = 0)
  batch_np_128 = np.delete(batch_np_128, 0, axis = 0)

  batch_np_64 = ((batch_np_64/255.0)-0.5)*2
  batch_np_128 = ((batch_np_128/255.0)-0.5)*2

  return batch_np_64, batch_np_128

# %%
def sample_images(epoch, img_path):
  epoch = epoch
  rows, cols = 4,3
  
  fig, ax = plt.subplots(rows,cols,figsize = (15,15))
  fig.tight_layout()
  counter = 0

  for i in range(0 ,rows*cols-1, cols):

    rand_index = np.random.choice(len(img_path))
    image_open = cv2.imread(img_path[rand_index])
    image_open = cv2.cvtColor(image_open, cv2.COLOR_BGR2RGB)

    image_64 = cv2.resize(image_open,(H,W), interpolation=cv2.INTER_CUBIC)
    image_128 = cv2.resize(image_open, (T_H,T_W))

    image_128 = image_128/255.0

    image_64_plot = image_64/255.0

    image_64 = ((image_64/255.0)-0.5)*2

    image_64 = np.expand_dims(image_64, axis= 0)

    fake_img = generator.predict(image_64)
    
    fake_img = np.reshape(fake_img, (T_H,T_W,T_C))
    
    fake_img = ((fake_img + 1)/2.0)
    

    plt.axis("off")
    ax[counter][0].imshow(image_64_plot)
    ax[counter][1].imshow(fake_img)
    ax[counter][2].imshow(image_128)
    

    counter += 1
  
  while True:
    file_name = file_path + f"/%d.png" %epoch
    if not os.path.exists(file_name):
      break     
    epoch += 2
    
    
  plt.savefig(file_name)
  plt.close()

# %%
# sample_images(0)

# %%
discriminator_losses = tf.keras.losses.BinaryCrossentropy()
generator_losses = tf.keras.losses.BinaryCrossentropy()
content_losses = tf.keras.losses.MeanSquaredError()

learning_rate = PiecewiseConstantDecay(boundaries = [100000], values = [1e-4, 1e-5])

gen_optimizer = Adam(learning_rate = learning_rate)
dis_optimizer = Adam(learning_rate = learning_rate)


def content_loss(real_imgs, fake_imgs):
  real_imgs = (real_imgs + 1)/2
  fake_imgs = (fake_imgs + 1)/2

  real_imgs = preprocess_input(real_imgs)
  fake_imgs = preprocess_input(fake_imgs)

  how_real_classified = VGG19_model(real_imgs)
  how_fake_classified = VGG19_model(fake_imgs)

  vgg_loss = content_losses(how_real_classified, how_fake_classified)
  

  return vgg_loss
  


def discriminator_loss(real_output, fake_output):
    real_loss = discriminator_losses(tf.ones_like(real_output), real_output)
    fake_loss = discriminator_losses(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    
    return total_loss

def generator_loss(fake_output):

    fake_loss = generator_losses(tf.ones_like(fake_output), fake_output)
    
    return fake_loss

# %%
def train_step(real_imgs, lr_imgs):
  
  with tf.GradientTape() as gen_tape, tf.GradientTape() as dis_tape:

    fake_hr_imgs = generator(lr_imgs, training = True)

    real_outputs = discriminator(real_imgs, training = True)
    fake_outputs = discriminator(fake_hr_imgs, training = True)

    d_loss = discriminator_loss(real_output = real_outputs, fake_output = fake_outputs)
    g_loss = generator_loss(fake_output = fake_outputs)
    c_loss = content_loss(real_imgs = real_imgs, fake_imgs=fake_hr_imgs)

    SR_loss = c_loss + 0.001*g_loss
    
    
    g_gradient = gen_tape.gradient(SR_loss, generator.trainable_variables)
    d_gradient = dis_tape.gradient(d_loss, discriminator.trainable_variables)

    gen_optimizer.apply_gradients(zip(g_gradient, generator.trainable_variables))
    dis_optimizer.apply_gradients(zip(d_gradient, discriminator.trainable_variables))

    return d_loss, SR_loss

# %%
# # since it take so long to extract all element in imagenet_2013 dataset, I choose to extract them one by one and delete them after training.

# import tarfile
# d_losses = tf.keras.metrics.Mean(name="d_loss")
# g_losses = tf.keras.metrics.Mean(name="g_loss")

# sample_path = glob("/content/drive/MyDrive/every_Gan/imagenet_2013/*.tar")
# file_number = 0
# for tar in sample_path:

#   file_number += 1

#   result_file_with_number = file_path + "file_sample_" + str(file_number)
#   file_name = "/content/extracted_tar"

#   if not os.path.exists(file_name):
#     os.makedirs(file_name)

  
  
#   my_tar = tarfile.open(tar)
#   my_tar.extractall(file_name)
#   my_tar.close()

#   img_p_1 = glob(file_name + "/*/*.JPEG")
#   img_p_2 = glob(file_name + "/*.JPEG")

#   img_path = img_p_1 + img_p_2

#   size_check(img_path)

#   img_p_1 = glob(file_name + "/*/*.JPEG")
#   img_p_2 = glob(file_name + "/*.JPEG")

#   img_path = img_p_1 + img_p_2


#   for epoch in range(epochs):
#     for batch in tqdm(range(0,len(img_path) - 1, batch_size)):
      
#       image_64, image_128 = image_to_numpy(batch_size = batch_size, batch = batch, img_path = img_path)


#       d_loss, SR_loss = train_step(real_imgs = image_128, lr_imgs = image_64)

#       d_losses.update_state(d_loss)
#       g_losses.update_state(SR_loss)
      
#     if epoch % sample_every == 0:
#       print(f"epoch : {epoch}/{epochs}   d_loss : {d_losses.result():0.5f}   g_loss : {g_losses.result():0.5f} ")
#       sample_images(epoch, img_path)
#       # check_point.step.assign_add(1)
      
#       d_losses.reset_states()
#       g_losses.reset_states()

#       check_point_manager.save()
#   shutil.rmtree(file_name, ignore_errors = True)

# %%
img_path = glob("data/mirflickr/*.jpg")
# print(f"img_path len : {len(img_path)}")


# for i in img_path:
#   image_open = cv2.imread(i)
#   image_size = image_open.shape

  
#   if image_size[0] < 256 or image_size[1] < 256:   
#     os.remove(i)

# img_path = glob("data/mirflickr/*.jpg")
# print(f"img_path len : {len(img_path)}")

# %%
# since it take so long to extract all element in imagenet_2013 dataset, I choose to extract them one by one and delete them after training.

d_losses = tf.keras.metrics.Mean(name="d_loss")
g_losses = tf.keras.metrics.Mean(name="g_loss")



for epoch in range(epochs):
    for batch in tqdm(range(0,len(img_path) - 1, batch_size)):
      
      image_64, image_128 = image_to_numpy(batch_size = batch_size, batch = batch, img_path = img_path)


      d_loss, SR_loss = train_step(real_imgs = image_128, lr_imgs = image_64)

      d_losses.update_state(d_loss)
      g_losses.update_state(SR_loss)
      
    if epoch % sample_every == 0:
      print(f"epoch : {epoch}/{epochs}   d_loss : {d_losses.result():0.5f}   g_loss : {g_losses.result():0.5f} ")
      sample_images(epoch, img_path)
      # check_point.step.assign_add(1)
      
      d_losses.reset_states()
      g_losses.reset_states()

      check_point_manager.save()
# Out:
# 100%|██████████| 12338/12338 [1:24:52<00:00,  2.42it/s]
# epoch : 0/1000   d_loss : 0.43380   g_loss : 76.53303
# 1/1 [==============================] - 1s 812ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 100%|██████████| 12338/12338 [1:25:48<00:00,  2.40it/s]
# 100%|██████████| 12338/12338 [1:25:51<00:00,  2.40it/s]
# 100%|██████████| 12338/12338 [1:23:51<00:00,  2.45it/s]
# 100%|██████████| 12338/12338 [1:23:10<00:00,  2.47it/s]
# 100%|██████████| 12338/12338 [1:24:34<00:00,  2.43it/s]
# epoch : 5/1000   d_loss : 0.02949   g_loss : 56.07910
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 100%|██████████| 12338/12338 [1:24:21<00:00,  2.44it/s]
# 100%|██████████| 12338/12338 [1:24:29<00:00,  2.43it/s]
# 100%|██████████| 12338/12338 [1:24:04<00:00,  2.45it/s]
# 100%|██████████| 12338/12338 [1:23:22<00:00,  2.47it/s]
# 100%|██████████| 12338/12338 [1:21:44<00:00,  2.52it/s]
# epoch : 10/1000   d_loss : 0.01728   g_loss : 48.65018
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 100%|██████████| 12338/12338 [1:21:32<00:00,  2.52it/s]
# 100%|██████████| 12338/12338 [1:21:28<00:00,  2.52it/s]
# 100%|██████████| 12338/12338 [1:21:25<00:00,  2.53it/s]
# 100%|██████████| 12338/12338 [1:21:39<00:00,  2.52it/s]
# 100%|██████████| 12338/12338 [1:22:22<00:00,  2.50it/s]
# epoch : 15/1000   d_loss : 0.00313   g_loss : 45.89977
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 100%|██████████| 12338/12338 [1:21:24<00:00,  2.53it/s]
# 100%|██████████| 12338/12338 [1:21:22<00:00,  2.53it/s]
# 100%|██████████| 12338/12338 [1:21:57<00:00,  2.51it/s]
# 100%|██████████| 12338/12338 [1:21:20<00:00,  2.53it/s]
# 100%|██████████| 12338/12338 [1:21:50<00:00,  2.51it/s]
# epoch : 20/1000   d_loss : 0.00093   g_loss : 44.78990
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 100%|██████████| 12338/12338 [1:21:56<00:00,  2.51it/s]
# 100%|██████████| 12338/12338 [1:15:55<00:00,  2.71it/s]
# 100%|██████████| 12338/12338 [1:17:47<00:00,  2.64it/s]
# 100%|██████████| 12338/12338 [1:20:50<00:00,  2.54it/s]
# 100%|██████████| 12338/12338 [1:19:41<00:00,  2.58it/s]
# epoch : 25/1000   d_loss : 0.00095   g_loss : 43.72190
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 100%|██████████| 12338/12338 [1:19:54<00:00,  2.57it/s]
# 100%|██████████| 12338/12338 [1:20:36<00:00,  2.55it/s]
# 100%|██████████| 12338/12338 [1:21:27<00:00,  2.52it/s]
# 100%|██████████| 12338/12338 [1:21:16<00:00,  2.53it/s]
# 100%|██████████| 12338/12338 [1:21:16<00:00,  2.53it/s]
# epoch : 30/1000   d_loss : 0.00004   g_loss : 42.73145
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 12ms/step
# 100%|██████████| 12338/12338 [1:21:15<00:00,  2.53it/s]
# 100%|██████████| 12338/12338 [1:21:17<00:00,  2.53it/s]
# 100%|██████████| 12338/12338 [1:21:26<00:00,  2.52it/s]
# 100%|██████████| 12338/12338 [1:20:42<00:00,  2.55it/s]
# 100%|██████████| 12338/12338 [1:19:43<00:00,  2.58it/s]
# epoch : 35/1000   d_loss : 0.00060   g_loss : 41.76362
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 16ms/step
# 100%|██████████| 12338/12338 [1:19:49<00:00,  2.58it/s]
# 100%|██████████| 12338/12338 [1:19:44<00:00,  2.58it/s]
# 100%|██████████| 12338/12338 [1:14:54<00:00,  2.75it/s]
# 100%|██████████| 12338/12338 [1:10:59<00:00,  2.90it/s]
# 100%|██████████| 12338/12338 [1:18:02<00:00,  2.63it/s]
# epoch : 40/1000   d_loss : 0.00103   g_loss : 40.81795
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
#  54%|█████▍    | 6724/12338 [43:30<36:19,  2.58it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [25], line 14
#       9 for batch in tqdm(range(0,len(img_path) - 1, batch_size)):
#      11   image_64, image_128 = image_to_numpy(batch_size = batch_size, batch = batch, img_path = img_path)
# ---> 14   d_loss, SR_loss = train_step(real_imgs = image_128, lr_imgs = image_64)
#      16   d_losses.update_state(d_loss)
#      17   g_losses.update_state(SR_loss)
#
# Cell In [22], line 12, in train_step(real_imgs, lr_imgs)
#      10 d_loss = discriminator_loss(real_output = real_outputs, fake_output = fake_outputs)
#      11 g_loss = generator_loss(fake_output = fake_outputs)
# ---> 12 c_loss = content_loss(real_imgs = real_imgs, fake_imgs=fake_hr_imgs)
#      14 SR_loss = c_loss + 0.001*g_loss
#      17 g_gradient = gen_tape.gradient(SR_loss, generator.trainable_variables)
#
# Cell In [21], line 21, in content_loss(real_imgs, fake_imgs)
#      18 how_real_classified = VGG19_model(real_imgs)
#      19 how_fake_classified = VGG19_model(fake_imgs)
# ---> 21 vgg_loss = content_losses(how_real_classified, how_fake_classified)
#      24 return vgg_loss
#
# File c:\Users\chois\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\losses.py:158, in Loss.__call__(self, y_true, y_pred, sample_weight)
#     154 reduction = self._get_reduction()
#     155 sample_weight = losses_utils.apply_valid_mask(
#     156     losses, sample_weight, mask, reduction
#     157 )
# --> 158 return losses_utils.compute_weighted_loss(
#     159     losses, sample_weight, reduction=reduction
#     160 )
#
# File c:\Users\chois\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\losses_utils.py:354, in compute_weighted_loss(losses, sample_weight, reduction, name)
#     351 weighted_losses = tf.multiply(losses, sample_weight)
#     353 # Apply reduction function to the individual weighted losses.
# --> 354 loss = reduce_weighted_loss(weighted_losses, reduction)
#     355 if input_casted:
#     356     # Convert the result back to the input type.
#     357     loss = tf.cast(loss, input_dtype)
#
# File c:\Users\chois\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\losses_utils.py:285, in reduce_weighted_loss(weighted_losses, reduction)
#     283     loss = tf.reduce_sum(weighted_losses)
#     284     if reduction == ReductionV2.SUM_OVER_BATCH_SIZE:
# --> 285         loss = _safe_mean(loss, _num_elements(weighted_losses))
#     286 return loss
#
# File c:\Users\chois\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\losses_utils.py:273, in _num_elements(losses)
#     271 """Computes the number of elements in `losses` tensor."""
#     272 with backend.name_scope("num_elements") as scope:
# --> 273     return tf.cast(tf.size(losses, name=scope), dtype=losses.dtype)
#
# File c:\Users\chois\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chois\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\chois\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\math_ops.py:1003, in cast(x, dtype, name)
#    1001   x = ops.convert_to_tensor(x, name="x")
#    1002   if x.dtype != base_type:
# -> 1003     x = gen_math_ops.cast(x, base_type, name=name)
#    1004 if x.dtype.is_complex and base_type.is_floating:
#    1005   logging.warn("Casting complex to real discards imaginary part.")
#
# File c:\Users\chois\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:1996, in cast(x, DstT, Truncate, name)
#    1994 if tld.is_eager:
#    1995   try:
# -> 1996     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    1997       _ctx, "Cast", name, x, "DstT", DstT, "Truncate", Truncate)
#    1998     return _result
#    1999   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
